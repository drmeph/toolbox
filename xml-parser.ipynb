# %%
import pandas as pd
import requests
import lxml

# %%
url = "https://www.treasury.gov/ofac/downloads/sdn.xml"

# %%
df = pd.read_xml(url)

# %%
df[df.lastName != None]
# Out:
#       Publish_Date  Record_Count      uid                   lastName  \
# 0       08/15/2022       10493.0      NaN                       None
# 1             None           NaN     36.0     AEROCARIBBEAN AIRLINES
# 2             None           NaN    173.0  ANGLO-CARIBBEAN CO., LTD.
# 3             None           NaN    306.0     BANCO NACIONAL DE CUBA
# 4             None           NaN    424.0         BOUTIQUE LA MAISON
# ...            ...           ...      ...                        ...
# 10489         None           NaN  38418.0              GLORY HARVEST
# 10490         None           NaN  38499.0               TORNADO CASH
# 10491         None           NaN  38516.0                    TWEHWAY
# 10492         None           NaN  38517.0                     CEPHUS
# 10493         None           NaN  38518.0                     MCGILL
#
#           sdnType  programList  akaList  addressList  idList       firstName  \
# ...
